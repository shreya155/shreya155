# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd


df = pd.read_csv ('C:\\Users\\shrey\\anaconda3\\Price.csv')
i = df.iloc [:,0].values
d = df.iloc [:,1].values

#print(i)
#print(d)
df
# Out:
#     Area (sqft)  Price ($)
# 0          2000      88600
# 1          1600      71600
# 2          1980      93300
# 3          1840      84300
# 4          1710      80600
# 5          1550      75200
# 6          1470      69700
# 7          1710      82000
# 8          1540      69400
# 9          1620      78700
# 10         1500      79600
# 11         1720      82600
# 12         1600      74500
# 13         1700      83500
# 14         1440      76300
# 15         1520      74000
# 16         1960      92890
# 17         1700      79500
# 18         1420      75600
# 19         1520      70000
# 20         1900      82600
# 21         1640      73600
# 22         1900      92100
# 23         1860      84700
# 24         1700      82600
# 25         1590      75900
# 26         1410      68700
# 27         1770      84700
# 28         1550      72400
# 29         1600      76700
# 30         1580      82600
# 31         1760      83600
# 32         1600      78500
# 33         1790      84500
# 34         1480      78500
# 35         1500      72000
# 36         1980      92990
# 37         1710      81500
# 38         1400      71300
# 39         1590      72500

# %%
from sklearn.model_selection import train_test_split
#from sklearn.cross_validation import train_test_split
x_train, x_test, y_train, y_test = train_test_split (i, d, test_size = .20)

#print("records in x_test")
#print(x_test)  # 8 records in x_test
#print(y_test) 
#print(x_train)
#print(y_train)	


#print("output of x_train before reshape is :")
#print(x_train)
x_train = x_train.reshape(-1,1)
#print(x_train)

y_train = y_train.reshape(-1,1)


#print("output of x_train after reshape is :")
#print(x_train)

# %%
#print("again reshaping")
#x_train = x_train.reshape(1,-1)
#print(x_train)
x_test = x_test.reshape(-1,1)

from sklearn.linear_model import LinearRegression
lnr = LinearRegression()
lnr.fit (x_train, y_train ) 

predicted_y = lnr.predict(x_test)
print("predicted y records:")
print(predicted_y)
print(y_test)
print(x_test)
# Out:
# predicted y records:
# [[82220.07398805]
#  [80126.61041077]
#  [76288.59385244]
#  [80475.52100699]
#  [75939.68325622]
#  [89896.10710473]
#  [89896.10710473]
#  [71054.93490925]]
# [83600 83500 75900 82000 82600 93300 92990 76300]
# [[1760]
#  [1700]
#  [1590]
#  [1710]
#  [1580]
#  [1980]
#  [1980]
#  [1440]]

# %%
from sklearn import metrics
from sklearn.metrics import mean_squared_error
from math import sqrt
print("RMSE is:-")

print('Mean Absolute Error(MAE):', metrics.mean_absolute_error(y_test, predicted_y))
print('Mean Squared Error(MSE):', metrics.mean_squared_error(y_test, predicted_y))
print('Root Mean Squared Error(RMSE):', np.sqrt(metrics.mean_squared_error(y_test, predicted_y)))
# Out:
# RMSE is:-
# Mean Absolute Error(MAE): 3133.694508962859
# Mean Squared Error(MSE): 13598522.69062883
# Root Mean Squared Error(RMSE): 3687.617481603648

# %%
plt.scatter(x_test, y_test, color = 'red')
plt.plot(x_test,predicted_y, color = 'green')
plt.title ('Results ')
plt.xlabel('Area of Flats')
plt.ylabel('Price')
plt.show()

# %%
#explain equation now y=mx+c
m=lnr.coef_
c=lnr.intercept_
print(m) #slope
print(c)  

y=m*1720+c  #Here i is x as defined above
print(y)
print(lnr.predict([[1720]]))
# Out:
# [[34.89105962]]
# [20811.80905464]
# [[80824.4316032]]
# [[80824.4316032]]

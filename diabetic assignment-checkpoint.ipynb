# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.read_csv("C:\\Users\\shrey\\anaconda3\\diabetes.csv")
import warnings
warnings.filterwarnings('ignore')
pd.read_csv("C:\\Users\\shrey\\anaconda3\\diabetes.csv")
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
#graph for glucose distribution
df=pd.read_csv("C:\\Users\\shrey\\anaconda3\\diabetes.csv")
sns.distplot(df['Glucose'])
plt.show()

# %%
#pregnancies distribution
sns.distplot(df['Pregnancies'])
plt.show()

# %%
#number of pregnancies in the particular age
df=pd.read_csv("C:\\Users\\shrey\\anaconda3\\diabetes.csv")
df.groupby(('Age'))[['Pregnancies']].max()
sns.factorplot('Age','Pregnancies',data=df,kind='bar',size=5,aspect=4)
plt.show()

# %%
#number of diabetic and non diabetic patients
sns.countplot(x='Outcome', data=df)
plt.show()

# %%
#non diabetic 
df['Outcome'].value_counts()
sns.distplot(df[df['Outcome']==0]['BloodPressure'])
plt.show()

# %%
df['Outcome'].value_counts()
sns.distplot(df[df['Outcome']==1]['BloodPressure'])
plt.show()

# %%
#number of diabetic and non diabetic  pregnant females with age 50 and above
df5=df[(df.Age>=50)]
df5['Outcome'].value_counts()
# Out:
# 0    46
# 1    43
# Name: Outcome, dtype: int64

# %%
#graph for number of diabetic and non diabetic  pregnant females with age 50 and above
df5=df[(df.Age>=50)]
sns.countplot(x='Outcome', data=df5)
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='count'>

# %%
#number of diabetic and non diabetic and pregnant females with age below 50 
df6=df[(df.Age<50)]
df6['Outcome'].value_counts()
# Out:
# 0    454
# 1    225
# Name: Outcome, dtype: int64

# %%
sns.countplot(x='Outcome', data=df6)
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='count'>

# %%
#histogram for blood pressure and skin thickness
features = ['BloodPressure', 'SkinThickness']
df[features].hist(figsize=(10, 4))
plt.show()

# %%
#number of diabetic and non diabetic and pregnant females with BMI greater than 24.99
#implies that the woman is overweight
df7=df[(df.BMI>24.99)]
df7['Outcome'].value_counts()
# Out:
# 0    392
# 1    259
# Name: Outcome, dtype: int64

# %%
sns.countplot(x='Outcome', data=df7)
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='count'>

# %%
#number of diabetic and non diabetic and pregnant females with BMI less than 18.5
#implies that the woman is underweight
df8=df[(df.BMI<18.5)]
df8['Outcome'].value_counts()
# Out:
# 0    13
# 1     2
# Name: Outcome, dtype: int64

# %%
sns.countplot(x='Outcome', data=df8)
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='count'>

# %%
#number of diabetic and non diabetic and pregnant females with BMI between 18.5 to 24.99
#healthy pregnancy
df8=df[(df.BMI<18.5)]

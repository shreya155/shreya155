# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df= pd.read_csv("C:\\Users\\Shreya Thakur\\anaconda3\\top50.csv")
import warnings
warnings.filterwarnings('ignore')
df
# Out:
#     Unnamed: 0                                         Track.Name  \
# 0            1                                           Se�orita
# 1            2                                              China
# 2            3                      boyfriend (with Social House)
# 3            4                    Beautiful People (feat. Khalid)
# 4            5                        Goodbyes (Feat. Young Thug)
# 5            6                  I Don't Care (with Justin Bieber)
# 6            7                                             Ransom
# 7            8                                  How Do You Sleep?
# 8            9                              Old Town Road - Remix
# 9           10                                            bad guy
# 10          11                                           Callaita
# 11          12              Loco Contigo (feat. J. Balvin & Tyga)
# 12          13                                  Someone You Loved
# ...

# %%
#  way of checking for dupliates
df[df.duplicated(subset=['Track.Name','Artist.Name'],keep=False)].count()
# Out:
# Unnamed: 0          0
# Track.Name          0
# Artist.Name         0
# Genre               0
# Beats.Per.Minute    0
# Energy              0
# Danceability        0
# Loudness..dB..      0
# Liveness            0
# Valence.            0
# Length.             0
# Acousticness..      0
# Speechiness.        0
# Popularity          0
# dtype: int64

# %%
#histogram for BPM and danceability
features = ['Beats.Per.Minute', 'Danceability']
df[features].hist(figsize=(10, 4))
plt.show()

# %%
#line graph
df.head()

# Width and height of figure
plt.figure(figsize=(10,6))
sns.lineplot(data=df, dashes=False)
plt.show()

# %%
#plotting mean of audio features
df.mean().plot.bar()
plt.title('Mean Values of Audio Features')
plt.show()

# %%
#total no of songs per genre
plt.figure(figsize=(6,7))
a=sns.countplot(df.Genre)
a.set(xlabel='Genre',
       ylabel='Total number of songs',
       title='Number of Songs represented by Genre');
plt.xticks(rotation=90)
plt.show()

# %%
#beats per minute for different genre
plt.figure(figsize=(6,6))
sns.barplot(x=df['Genre'], y=df['Beats.Per.Minute'], palette='twilight_shifted')
plt.xticks(rotation=90)
plt.show()

# %%
df.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Se�orita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
le= LabelEncoder()
df['Track.Name']= le.fit_transform(df['Track.Name'])

# %%
le= LabelEncoder()
df['Artist.Name']= le.fit_transform(df['Artist.Name'])

# %%
le= LabelEncoder()
df['Genre']= le.fit_transform(df['Genre'])

# %%
#number of tracks with genre - pop
df2=df[(df.Genre=='Pop')]
df2['Track.Name'].value_counts()
# Out:
# Series([], Name: Track.Name, dtype: int64)

# %%
y = df.loc[:, 'Popularity']
X = df.drop('Popularity', axis=1)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X = scaler.fit_transform(X)

# %%
import plotly.express as px
from sklearn.model_selection import train_test_split
xtrain, xtest, ytrain, ytest = train_test_split(X, y, train_size=0.26, random_state=20)

# %%
df.drop('Loudness..dB..',axis='columns', inplace=True)

# %%
#using linear regression model
from sklearn import linear_model
from sklearn.model_selection import train_test_split
from sklearn import metrics
# Set prediction target which will be Popularity
y = df.Popularity
# Features used to predict
features = ["Beats.Per.Minute", "Energy", "Danceability"
            , "Liveness", "Valence.","Length.","Acousticness.."
            ,"Speechiness."]

X = df[features]

# %%
from sklearn.model_selection import train_test_split
#from sklearn.cross_validation import train_test_split
x_train, x_test, y_train, y_test = train_test_split (X, y, test_size = .20)

# %%
from sklearn.linear_model import LinearRegression
lnr = LinearRegression()
lnr.fit (x_train, y_train ) 

predicted_y = lnr.predict(x_test)
print("predicted y records:")
print(predicted_y)
print(y_test)
print(x_test)
# Out:
# predicted y records:
# [89.56559957 91.5213832  84.19190299 80.91613632 88.57906246 87.7438586
#  87.61049961 86.20104134 87.8226666  85.72846062]
# 34    89
# 15    82
# 38    80
# 17    91
# 19    91
# 3     86
# 32    89
# 21    91
# 4     94
# 47    88
# Name: Popularity, dtype: int64
#     Beats.Per.Minute  Energy  Danceability  Liveness  Valence.  Length.  \
# 34               100      88            77        32        39      224
# 15                93      45            70        16        14      261
# 38               138      73            84        11        95      181
# 17                90      48            76         7        91      158
# 19               158      62            72        12        41      173
# 3                 93      65            64         8        55      198
# 32                96      71            78         9        68      176
# 21               154      59            70        12        48      115
# ...

# %%
df3=pd.DataFrame(predicted_y)
print('Popularity prediction:')
df3
# Out:
# Popularity prediction:
#            0
# 0  89.565600
# 1  91.521383
# 2  84.191903
# 3  80.916136
# 4  88.579062
# 5  87.743859
# 6  87.610500
# 7  86.201041
# 8  87.822667
# 9  85.728461

# %%
#finding errors
from sklearn import metrics
from sklearn.metrics import mean_squared_error
from math import sqrt
import numpy as np
print("RMSE is:-")

print('Mean Absolute Error(MAE):', metrics.mean_absolute_error(y_test, predicted_y))
print('Mean Squared Error(MSE):', metrics.mean_squared_error(y_test, predicted_y))
print('Root Mean Squared Error(RMSE):', np.sqrt(metrics.mean_squared_error(y_test, predicted_y)))
# Out:
# RMSE is:-
# Mean Absolute Error(MAE): 4.316487740490464
# Mean Squared Error(MSE): 28.741503429166233
# Root Mean Squared Error(RMSE): 5.361110279519181

# %%
x_test.head()
# Out:
#     Beats.Per.Minute  Energy  Danceability  Liveness  Valence.  Length.  \
# 34               100      88            77        32        39      224
# 15                93      45            70        16        14      261
# 38               138      73            84        11        95      181
# 17                90      48            76         7        91      158
# 19               158      62            72        12        41      173
#
#     Acousticness..  Speechiness.
# 34              19             6
# 15              12            15
# 38               4             6
# 17              56             5
# 19              11            11

# %%
y_test.head()
# Out:
# 34    89
# 15    82
# 38    80
# 17    91
# 19    91
# Name: Popularity, dtype: int64

# %%
df= pd.read_csv("C:\\Users\\Shreya Thakur\\anaconda3\\top50.csv")
df.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Se�orita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %%
X = df.iloc[:, 6:7].values
y = df.iloc[:, -1].values

# %%
X
# Out:
# array([[76],
#        [79],
#        [40],
#        [64],
#        [58],
#        [80],
#        [75],
#        [48],
#        [88],
#        [70],
#        [61],
#        [82],
#        [50],
#        [73],
#        [83],
#        [70],
#        [75],
#        [76],
#        [84],
#        [72],
#        [68],
#        [70],
#        [81],
#        [80],
#        [67],
#        [69],
#        [82],
#        [73],
#        [74],
#        [64],
#        [29],
#        [78],
#        [78],
#        [80],
#        [77],
#        [66],
#        [75],
#        [72],
#        [84],
#        [81],
#        [69],
#        [77],
#        [57],
#        [90],
#        [88],
#        [66],
#        [67],
#        [69],
#        [59],
#        [75]], dtype=int64)

# %%
y
# Out:
# array([79, 92, 85, 86, 94, 84, 92, 90, 87, 95, 93, 86, 88, 87, 92, 82, 90,
#        91, 88, 91, 91, 91, 83, 91, 89, 70, 83, 89, 91, 89, 84, 89, 89, 89,
#        89, 89, 91, 87, 80, 78, 88, 90, 87, 84, 88, 88, 88, 88, 88, 82],
#       dtype=int64)

# %%
#polynomial regression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
poly_reg = PolynomialFeatures(degree = 9)
X_poly = poly_reg.fit_transform(X)
lin_reg = LinearRegression()
lin_reg.fit(X_poly, y)
# Out:
# LinearRegression()

# %%
y_pred = lin_reg.predict(X_poly)

# %%
df = pd.DataFrame({'Real Values':y, 'Predicted Values':y_pred})
df.head()
# Out:
#    Real Values  Predicted Values
# 0           79         87.769789
# 1           92         87.415675
# 2           85         85.360754
# 3           86         88.470852
# 4           94         89.621163

# %%
X_grid = np.arange(min(X), max(X),0.1)
X_grid = X_grid.reshape((len(X_grid), 1))
plt.scatter(X, y, color = 'red')
plt.scatter(X, y_pred, color = 'green')
plt.plot(X_grid, lin_reg.predict(poly_reg.fit_transform(X_grid)), color = 'black')
plt.title('Polynomial Regression')
plt.xlabel('Popularity')
plt.ylabel('Danceability')
plt.show()
